# %%
from sql_utils import WebScrapingDB
db = WebScrapingDB(None)
db.create_database()

db = WebScrapingDB()
db.create_table()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sql_utils import WebScrapingDB
#       2 db = WebScrapingDB(None)
#       3 db.create_database()
#       4
#
# File c:\Users\student\AIPE_class\PyMySQL_1\pymysql_d3\Chapter5\sql_utils.py:1
# ----> 1 import pymysql
#       2 from configparser import ConfigParser
#       4 config = ConfigParser()
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
db = WebScrapingDB()
db.insert_store('PCHome',"https://24h.pchome.com.tw/" )
db.insert_store('Momo',"https://www.momoshop.com.tw/main/Main.jsp" )
