# %%
# %pip install request bs4 lxml selenium
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for request

# %%
# %pip install BeautifulSuop
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement BeautifulSuop (from versions: none)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for BeautifulSuop

# %%
import requests
from bs4 import BeautifulSoup as bs
url = "https://store.line.me/stickershop/product/33904260/zh-Hant"

res = requests.get(url)

print(res)

soup = bs(res.text, "lxml")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import requests
# ----> 2 import bs
#       3 url = "https://store.line.me/stickershop/product/33904260/zh-Hant"
#       4
#       5 res = requests.get(url)
#
# ModuleNotFoundError: No module named 'bs'

# %%
import json
import os

folder = 'line_stickers'
if not os.path.exists(folder):
    os.mkdir('line_stickers'
             )
elements = soup.select("ul.mdCMN09Ul.FnStickerList > li")
print(len(elements))

for element in elements:
    print(element)
    img_element = json.loads(element['data-preview'])
    img_url = element['data-preview']
    print(img_url)
    n += 1
    with open(f'{folder}/sticker_{n}.png', mode='wb') as img:
        img.write(requests.get(img_url).content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 elements = soup.select("ul.mdCMN09Ul.FnStickerList > li")
#       2 print(len(elements))
#       3
#       4 for element in elements:
#
# NameError: name 'soup' is not defined

# %%
url='
https://store.line.me/api/search/sticker?category=sticker&type=ALL&offset=0&limit=36&includeFacets=true&query=%E8%83%B8%E6%AF%9B%E5%85%AC%E5%AF%93'

cookies = {
    'dispaly_lang' : 'zh-Hant'
}

r = requests.get(url % "胸毛公寓", cookies=cookies)
print(r.json())
