# %% [markdown]
# 讀取設定檔

# %%
# 引入模組
from configparser import ConfigParser
# 讀取 config.ini 檔案取得資料庫連線資訊
config = ConfigParser()
config.read("config.ini")
print(config)


# 讀取 DB 區塊
print(config["DB"])

# 讀取 host
print(config["DB"]['host'])

# 讀取 user
print(config["DB"]["user"])

print(config['OPENAPI']["API_KEY"])
# Out:
# <configparser.ConfigParser object at 0x000002D2DBDD5B50>
# <Section: DB>
# localhost
# root
# FDFDFA

# %% [markdown]
# 使用設定檔建立資料庫連線

# %%
import pymysql
from configparser import ConfigParser

# 讀取 config.ini 檔案取得資料庫連線資訊
config = ConfigParser()
config.read("config.ini")
# 建立資料庫連線
connection = pymysql.connect(
    host=config.get('DB', 'host'),
    user=config.get('DB', 'user'),
    password=config.get('DB', 'password'),
    port=config.getint('DB', 'port'),
    # port 拿倒是字串, 所以要強制轉成 int
    cursorclass=pymysql.cursors.DictCursor,
)

with connection.cursor() as cursor:
    query = """
        SHOW DATABASES;
    """
    cursor.execute(query)
    result = cursor.fetchall()
print(result)
# Out:
# [{'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_databases'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'transaction_test'}, {'Database': 'world'}]

# %%
print(config.get('DB', 'host'))
print(config.get('DB', 'password'))
print(config.get('DB', 'port'))
# Out:
# localhost
# Fasans2552314
# 3306

# %% [markdown]
# 使用 SQL 函式

# %%
def sql_query(sql):
    with connection.cursor() as cursor:
        cursor.execute(sql)
        result = cursor.fetchall()
    return result
data = sql_query("SHOW DATABASES;")
print(data)
# Out:
# [{'Database': 'classicmodels'}, {'Database': 'information_schema'}, {'Database': 'my_databases'}, {'Database': 'my_titanic'}, {'Database': 'my_train_titanic'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sakila'}, {'Database': 'social_media_app'}, {'Database': 'sys'}, {'Database': 'transaction_test'}, {'Database': 'world'}]

# %%
from sql_utils import SqlManager

db = SqlManager()
result = db.sql_query(SqlManager.dbs)
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       1 from sql_utils import SqlManager
#       2
#       3 db = SqlManager()
# ----> 4 result = db.sql_query(SqlManager.dbs)
#       5 print(result)
#
# File c:\Users\student\AIPE_class\PyMySQL_1\pymysql_d3\Chapter1\sql_utils.py:24, in SqlManager.sql_query(self, sql)
#      23 def sql_query(self, sql):
# ---> 24     with self.connection.cursor() as cursor:
#      25         cursor.execute(sql)
#      26         result = cursor.fetchall()
#
# AttributeError: 'SqlManager' object has no attribute 'connection'

# %%
from sql_utils import SqlManager
from pprint import pprint

db = SqlManager()
result = db.sql_query(SqlManager.full_passengers)
print(result[0], sort_dicts=False)

# ID, pclass, pname
leonard_male = []

for i in result:
    if 'Leonard' in i["pname"] and i["sex"] == "male" and i['pname'].startswith ('Leonard') is False: 
        leonard_male.append({
            "id" : i['id'],
            'pclass' : i['pclass'],
            'pname' : i['pname']
        })

print(len(leonard_male))
print(leonard_male, sort_dicts=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       1 from sql_utils import SqlManager
#       2 from pprint import pprint
#       3
#       4 db = SqlManager()
# ----> 5 result = db.sql_query(SqlManager.full_passengers)
#       6 print(result[0], sort_dicts=False)
#       7
#       8 # ID, pclass, pname
#
# File c:\Users\student\AIPE_class\PyMySQL_1\pymysql_d3\Chapter1\sql_utils.py:24, in SqlManager.sql_query(self, sql)
#      23 def sql_query(self, sql):
# ---> 24     with self.connection.cursor() as cursor:
#      25         cursor.execute(sql)
#      26         result = cursor.fetchall()
#
# AttributeError: 'SqlManager' object has no attribute 'connection'

# %%
from sql_utils import SqlManager
from pprint import pprint

db = SqlManager()
result = db.get_leonard_males()
print(result, sort_dicts=False)
